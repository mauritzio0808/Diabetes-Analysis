# %% [markdown]
# # Foundations of Data Science Project - Diabetes Analysis
#
# ---------------
# ## Context
# ---------------
#
# Diabetes is one of the most frequent diseases worldwide and the number of diabetic patients are growing over the years. The main cause of diabetes remains unknown, yet scientists believe that both genetic factors and environmental lifestyle play a major role in diabetes.
#
# A few years ago research was done on a tribe in America which is called the Pima tribe (also known as the Pima Indians). In this tribe, it was found that the ladies are prone to diabetes very early. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients were females at least 21 years old of Pima Indian heritage.
#
# -----------------
# ## Objective
# -----------------
#
# Here, we are analyzing different aspects of Diabetes in the Pima Indians tribe by doing Exploratory Data Analysis.
#
# -------------------------
# ## Data Dictionary
# -------------------------
#
# The dataset has the following information:
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: A function that scores the likelihood of diabetes based on family history.
# * Age: Age in years
# * Outcome: Class variable (0: a person is not diabetic or 1: a person is diabetic)

# %% [markdown]
# ## Q 1: Import the necessary libraries and briefly explain the use of each library (3 Marks)

# %%
import numpy as np
import pandas as pd
import seaborn as sns     
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 1: Necessary libraries
# * Numpy is a library used for working with arrays
# * Pandas is a library used for data manipulation and analysis
# * Seaborn is a library for visualization
# * Matplotlib is a library for visualization

# %% [markdown]
# ## Q 2: Read the given dataset (1 Mark)

# %%
pima = pd.read_csv("diabetes.csv")

# %% [markdown]
# ## Q3. Show the last 10 records of the dataset. How many columns are there? (1 Mark)

# %%
pima.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76             20       79  37.5
# 759            6      190             92             20       79  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31       79  44.0
# 762            9       89             62             20       79  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27       79  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60             20       79  30.1
# 767            1       93             70             31       79  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
pima.shape
# Out:
# (768, 9)

# %%
pima.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 3:
# * There are 9 columns with the next column names: 'Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'

# %% [markdown]
# ## Q4. Show the first 10 records of the dataset (1 Mark)

# %%
pima.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0            6      148             72             35       79  33.600000
# 1            1       85             66             29       79  26.600000
# 2            8      183             64             20       79  23.300000
# 3            1       89             66             23       94  28.100000
# 4            0      137             40             35      168  43.100000
# 5            5      116             74             20       79  25.600000
# 6            3       78             50             32       88  31.000000
# 7           10      115             69             20       79  35.300000
# 8            2      197             70             45      543  30.500000
# 9            8      125             96             20       79  31.992578
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# ...

# %% [markdown]
# ## Q5. What do you understand by the dimension of the dataset? Find the dimension of the `pima` dataframe. (1 Mark)

# %%
pima.shape
# Out:
# (768, 9)

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 5:
# * There are a 768 rows and 9 columns

# %% [markdown]
# ## Q6. What do you understand by the size of the dataset? Find the size of the `pima` dataframe. (1 Mark)

# %%
pima.size
# Out:
# 6912

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 6:
# * The total number of data points in the base is 6912 and it comes from the multiplication of rows and columns in the dataframe 768x9= 6,912

# %% [markdown]
# ## Q7. What are the data types of all the variables in the data set? (2 Marks)
# **Hint: Use the info() function to get all the information about the dataset.**

# %%
pima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 7:
# * 7 of the variables are integers and 2 of the variables are float

# %% [markdown]
# ## Q8. What do we mean by missing values? Are there any missing values in the `pima` dataframe? (2 Marks)

# %%
pima.isnull().values.any()
# Out:
# False

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 8:
# * There are no missing values in the DataFrame prima

# %% [markdown]
# ## Q9. What do the summary statistics of the data represent? Find the summary statistics for all variables except 'Outcome' in the `pima` data. Take one column/variable from the output table and explain all its statistical measures. (3 Marks)

# %%
pima.iloc[:,0:8].describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.675781      72.250000      26.447917  118.270833
# std       3.369578   30.436252      12.117203       9.733872   93.243829
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.000000   79.000000
# 50%       3.000000  117.000000      72.000000      23.000000   79.000000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    32.450805                  0.471876   33.240885
# std      6.875374                  0.331329   11.760232
# min     18.200000                  0.078000   21.000000
# ...

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 9:
# * The Pregnancies variable is made of 768 data points and the mean of pregnancies of women in the Prima Tribe is 3.8 with a standard deviation of 3.3 from the mean. The minimum number of pregnancies of a woman is 0 and the maximum it has been 17. Finally, the quartiles of the variable: 25% of the data are equal or less than 1 pregnancy, 50% are equal or less than 3 pregnancies and 75% are equal or less than 6.

# %% [markdown]
# ## Q 10. Plot the distribution plot for the variable 'BloodPressure'. Write detailed observations from the plot. (2 Marks)

# %%
# remove _____ & write the appropriate library name

sns.displot(data=pima, x=pima['BloodPressure'], kind='kde')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 10:
# * The graphic shows that most of the data is heavily concentrated around the mean that is 72.25 so the shape bell of the distribution is very narrow.

# %% [markdown]
# ## Q 11. What is the 'BMI' of the person having the highest 'Glucose'? (1 Mark)

# %%
pima[pima['Glucose']==pima['Glucose'].max()]['BMI']
# Out:
# 661    42.9
# Name: BMI, dtype: float64

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 11:
# * The BMI of the person with the highest Glucose is 42.9

# %% [markdown]
# ## Q12.
# ### 12.1 What is the mean of the variable 'BMI'?
# ### 12.2 What is the median of the variable 'BMI'?
# ### 12.3 What is the mode of the variable 'BMI'?
# ### 12.4 Are the three measures of central tendency equal?
#
# ### (3 Marks)

# %%
m1 = round(pima['BMI'].mean(),2)  # mean
print(m1)
m2 = pima['BMI'].median()  # median
print(m2)
m3 = pima['BMI'].mode()[0]  # mode
print(m3)
# Out:
# 32.45
# 32.0
# 32.0

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 12:
# * 12.1 mean= 32.45
# * 12.2 median= 32
# * 12.3 mode= 32
# * The most common measures of central tendency are the arithmetic mean, the median, and the mode.

# %% [markdown]
# ## Q13. How many women's 'Glucose' levels are above the mean level of 'Glucose'? (1 Mark)

# %%
pima[pima['Glucose']>pima['Glucose'].mean()].shape[0]
# Out:
# 343

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 13:
# * 343 women are above the mean level of Glucose

# %% [markdown]
# ## Q14. How many women have their 'BloodPressure' equal to the median of 'BloodPressure' and their 'BMI' less than the median of 'BMI'? (2 Marks)

# %%
pima[(pima['BloodPressure']==pima['BloodPressure'].median()) & (pima['BMI']<pima['BMI'].median())].shape[0]
# Out:
# 22

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 14:
# * 22 women have the characteristics of having their 'BloodPressure' equal to the median of 'BloodPressure' and their 'BMI' less than the median of 'BMI'

# %% [markdown]
# ## Q15. Create a pairplot for the variables 'Glucose', 'SkinThickness', and 'DiabetesPedigreeFunction'. Write your observations from the plot. (4 Marks)

# %%
sns.pairplot(data=pima,vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 15:
# * The pairplot graph in this case compares Glucose, Skin Thickness and Diabetes Pedigree Function against each other and for each variable shows the outcome for person having diabetes or not.
# * For the  diagonal plots, that is a univariate distribution plot, shows the distribution of the variable depending of the outcome.
# * Reviewing each comparasion we can see where there is a stong correlation or not. In one hand, it seems there is a strong correlation for women with high glucose and high likelihood of Diabetes Pedigree Function with the outcome of having diabetes. On the other hand, it seems there is no any correlation between Skin Thickness and Diabetes Pedigree Function.

# %% [markdown]
# ## Q16. Plot the scatterplot between 'Glucose' and 'Insulin'. Write your observations from the plot. (2 Marks)

# %%
sns.scatterplot (x='Glucose',y='Insulin',data=pima)
plt.show()

# %%
sns.scatterplot (x='Glucose',y='Insulin', hue="Outcome" , data=pima)
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# ## Ans 16:
# * From the graph it seems there is a weak positive correlation of more levels of glucose with more insulin. But if we add to the graph the variable of Outcome we can see that more glucose means higher probability of Diabetes but it is not necessary the case with insulin, meaning that more insulin doesn´t necessary means an outcome of diabetes.

# %% [markdown]
# ## Q 17. Plot the boxplot for the 'Age' variable. Are there outliers? (2 Marks)

# %%
plt.boxplot(pima['Age'])

plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

# %%
ax = sns.boxplot(x=pima['Age'])

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 17:
# * The boxplot shows where the median is, in this case around 28, and also the first and third quartile that represents the amount of data concentrated in each case. Finally there are 5 data points that are outliers for the variable of Age and the maximum value is 81.

# %% [markdown]
# ## Q18. Plot histograms for the 'Age' variable to understand the number of women in different age groups given whether they have diabetes or not. Explain both histograms and compare them. (3 Marks)

# %%
plt.hist(pima[pima['Outcome']==1]['Age'], color="g", bins = 5)
plt.title('Distribution of Age for Women who has Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(pima[pima['Outcome']==0]['Age'], color="g", bins = 5)
plt.title('Distribution of Age for Women who do not have Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(data=pima, x="Age", hue="Outcome", multiple="dodge")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 18:
# * The graph shows that the majority of the women below 30 years old do not have Diabetes but after 30 years old it is pretty equal for each age represented with and with no diabetes.

# %% [markdown]
# ## Q 19. What is the Interquartile Range of all the variables? Why is this used? Which plot visualizes the same? (2 Marks)

# %%
Q1 = pima.quantile(0.25)
Q3 = pima.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Pregnancies                  5.0000
# Glucose                     40.5000
# BloodPressure               16.0000
# SkinThickness               12.0000
# Insulin                     48.2500
# BMI                          9.1000
# DiabetesPedigreeFunction     0.3825
# Age                         17.0000
# Outcome                      1.0000
# dtype: float64

# %%
plt.figure(figsize = (15,8))
sns.boxplot(data=pima, palette="Set2")
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# ## Ans 19:
# * The interquartile range measures the spread of the middle half of the data and that equals to the median where 50% of the data is to the right and 50% to the left.
# * The median or the second interquartile is used to know where is the central value of the data.
# * The boxplot shows the interquartiles

# %% [markdown]
# ## Q 20. Find and visualize the correlation matrix. Write your observations from the plot. (3 Marks)

# %%
corr_matrix = pima.iloc[:,0:8].corr()
corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128022       0.208987       0.009393
# Glucose                      0.128022  1.000000       0.219765       0.158060
# BloodPressure                0.208987  0.219765       1.000000       0.130403
# SkinThickness                0.009393  0.158060       0.130403       1.000000
# Insulin                     -0.018780  0.396137       0.010492       0.245410
# BMI                          0.021546  0.231464       0.281222       0.532552
# DiabetesPedigreeFunction    -0.033523  0.137158       0.000471       0.157196
# Age                          0.544341  0.266673       0.326791       0.020582
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.018780  0.021546                 -0.033523
# Glucose                   0.396137  0.231464                  0.137158
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(corr_matrix, annot = True, cmap="YlGnBu")

# display the plot
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# ## Ans 20:
# * Correlations are useful because they can indicate a predictive relationship that can be exploited in practice specially for econometric regressions. In this case the strongest correlation are above .5 as we can see in the heat map between Pregnancies & Age and Skin Thickness & BMI.
